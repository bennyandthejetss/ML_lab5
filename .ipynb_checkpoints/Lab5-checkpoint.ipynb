# %% [markdown]
# # Lab Assignment Five: Wide and Deep Network Architectures

# %% [markdown]
# Group: Benjamin Kuo, Nicholas Benso
#
# ## Dataset Selection
#
# Select a dataset similarly to lab one. That is, the dataset must be table data. In terms of generalization performance, it is helpful to have a large dataset for building a wide and deep network. It is also helpful to have many different categorical features to create the embeddings and cross-product embeddings. It is fine to perform binary classification, multi-class classification, or regression.

# %% [markdown]
# ## Preparation (4 points total)
# [1 points] Define and prepare your class variables. Use proper variable representations (int, float, one-hot, etc.). Use pre-processing methods (as needed) for dimensionality reduction, scaling, etc. Remove variables that are not needed/useful for the analysis. Describe the final dataset that is used for classification/regression (include a description of any newly formed variables you created).
#
# [1 points] Identify groups of features in your data that should be combined into cross-product features. Provide justification for why these features should be crossed (or why some features should not be crossed).
#
# [1 points] Choose and explain what metric(s) you will use to evaluate your algorithm’s performance. You should give a detailed argument for why this (these) metric(s) are appropriate on your data. That is, why is the metric appropriate for the task (e.g., in terms of the business case for the task). Please note: rarely is accuracy the best evaluation metric to use. Think deeply about an appropriate measure of performance.
#
# [1 points] Choose the method you will use for dividing your data into training and testing (i.e., are you using Stratified 10-fold cross validation? Shuffle splits? Why?). Explain why your chosen method is appropriate or use more than one method as appropriate. Argue why your cross validation method is a realistic mirroring of how an algorithm would be used in practice.

# %%
import os
current_dir = os.getcwd()
print(current_dir)
# Out:
# C:\Users\benny\Jupyter\Lab5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import expit
import sys


# data - https://www.kaggle.com/datasets/sakshigoyal7/credit-card-customers

df = pd.read_csv(current_dir + "//BankChurners.csv") # read in the csv file

df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
#  3   Gender                                                                                                                              10127 non-null  object
#  4   Dependent_count                                                                                                                     10127 non-null  int64
#  5   Education_Level                                                                                                                     10127 non-null  object
#  6   Marital_Status                                                                                                                      10127 non-null  object
#  7   Income_Category                                                                                                                     10127 non-null  object
#  8   Card_Category                                                                                                                       10127 non-null  object
#  9   Months_on_book                                                                                                                      10127 non-null  int64
#  10  Total_Relationship_Count                                                                                                            10127 non-null  int64
#  11  Months_Inactive_12_mon                                                                                                              10127 non-null  int64
#  12  Contacts_Count_12_mon                                                                                                               10127 non-null  int64
#  13  Credit_Limit                                                                                                                        10127 non-null  float64
#  14  Total_Revolving_Bal                                                                                                                 10127 non-null  int64
#  15  Avg_Open_To_Buy                                                                                                                     10127 non-null  float64
#  16  Total_Amt_Chng_Q4_Q1                                                                                                                10127 non-null  float64
#  17  Total_Trans_Amt                                                                                                                     10127 non-null  int64
#  18  Total_Trans_Ct                                                                                                                      10127 non-null  int64
#  19  Total_Ct_Chng_Q4_Q1                                                                                                                 10127 non-null  float64
#  20  Avg_Utilization_Ratio                                                                                                               10127 non-null  float64
#  21  Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  10127 non-null  float64
#  22  Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  10127 non-null  float64
# dtypes: float64(7), int64(10), object(6)
# memory usage: 1.8+ MB
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# count                                       10127.000000
# mean                                            0.159997
# std                                             0.365301
# min                                             0.000008
# 25%                                             0.000099
# 50%                                             0.000181
# 75%                                             0.000337
# max                                             0.999580
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# count                                       10127.000000
# mean                                            0.840003
# std                                             0.365301
# min                                             0.000420
# 25%                                             0.999660
# 50%                                             0.999820
# 75%                                             0.999900
# max                                             0.999990

# %%
del df['CLIENTNUM']
del df['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1']
del df['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2']

# %%
from sklearn.model_selection import StratifiedKFold

X = df.drop(columns=['Attrition_Flag'])
y = df['Attrition_Flag']

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=1)

for train_index, test_index in skf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

df_train = pd.concat([X_train, y_train], axis=1)
df_test = pd.concat([X_test, y_test], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

encoders = dict()
categorical_headers = ['Gender','Education_Level','Marital_Status','Income_Category','Card_Category']

for col in categorical_headers+['Attrition_Flag']:
    df_train[col] = df_train[col].str.strip()
    df_test[col] = df_test[col].str.strip()
    
    if col=="Attrition_Flag":
        # special case the target, just replace the column
        tmp = LabelEncoder()
        df_train[col] = tmp.fit_transform(df_train[col])
        df_test[col] = tmp.transform(df_test[col])
    else:
        # integer encode strings that are features
        encoders[col] = LabelEncoder() # save the encoder
        df_train[col+'_int'] = encoders[col].fit_transform(df_train[col])
        df_test[col+'_int'] = encoders[col].transform(df_test[col])


numeric_headers = ["Customer_Age", "Dependent_count", "Months_on_book","Total_Relationship_Count", "Months_Inactive_12_mon", "Contacts_Count_12_mon", "Credit_Limit", "Total_Revolving_Bal", "Avg_Open_To_Buy", "Total_Amt_Chng_Q4_Q1", "Total_Trans_Amt", "Total_Trans_Ct", "Total_Ct_Chng_Q4_Q1", "Avg_Utilization_Ratio"]

ss = StandardScaler()
df_train[numeric_headers] = ss.fit_transform(df_train[numeric_headers].values)
df_test[numeric_headers] = ss.transform(df_test[numeric_headers].values)

categorical_headers_ints = [x+'_int' for x in categorical_headers]
feature_columns = categorical_headers_ints+numeric_headers

X_train = df_train[feature_columns].to_numpy()
X_test = df_test[feature_columns].to_numpy()

y_train = df_train['Attrition_Flag'].values.astype(np.int32)
y_test = df_test['Attrition_Flag'].values.astype(np.int32)

# %% [markdown]
# ## Modeling (5 points total)
# [2 points] Create at least three combined wide and deep networks to classify your data using Keras. Visualize the performance of the network on the training data and validation data in the same plot versus the training iterations. Note: use the "history" return parameter that is part of Keras "fit" function to easily access this data.
#
# [2 points] Investigate generalization performance by altering the number of layers in the deep branch of the network. Try at least two different number of layers. Use the method of cross validation and evaluation metric that you argued for at the beginning of the lab to select the number of layers that performs superiorly.
#
# [1 points] Compare the performance of your best wide and deep network to a standard multi-layer perceptron (MLP). Alternatively, you can compare to a network without the wide branch (i.e., just the deep network). .

# %% [markdown]
# ## Deep and Wide Network #1

# %%
from sklearn import metrics as mt
import tensorflow as tf
from tensorflow import keras
import os
from tensorflow.keras.layers import Dense, Activation, Input
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import concatenate

cross_columns = [['Education_Level', 'Income_Category'],['Gender', 'Marital_Status']]

# cross each set of columns in the list above
cross_col_df_names = []
for cols_list in cross_columns:
    # encode as ints for the embedding
    enc = LabelEncoder()
    
    # 1. create crossed labels by join operation
    X_crossed_train = df_train[cols_list].apply(lambda x: '_'.join(x), axis=1)
    X_crossed_test = df_test[cols_list].apply(lambda x: '_'.join(x), axis=1)
    
    # get a nice name for this new crossed column
    cross_col_name = '_'.join(cols_list)
    
    # 2. encode as integers, stacking all possibilities
    enc.fit(np.hstack((X_crossed_train.to_numpy(),  X_crossed_test.to_numpy())))
    
    # 3. Save into dataframe with new name
    df_train[cross_col_name] = enc.transform(X_crossed_train)
    df_test[cross_col_name] = enc.transform(X_crossed_test)
    
    # Save the encoder used here for later:
    encoders[cross_col_name] = enc
    
    # keep track of the new names of the crossed columns
    cross_col_df_names.append(cross_col_name) 
    
cross_col_df_names
# Out:
# ['Education_Level_Income_Category', 'Gender_Marital_Status']

# %%
# get crossed columns
X_train_crossed = df_train[cross_col_df_names].to_numpy()
X_test_crossed = df_test[cross_col_df_names].to_numpy()

# save categorical features
X_train_cat = df_train[categorical_headers_ints].to_numpy() 
X_test_cat = df_test[categorical_headers_ints].to_numpy() 

# and save off the numeric features
X_train_num =  df_train[numeric_headers].to_numpy()
X_test_num = df_test[numeric_headers].to_numpy()


# we need to create separate lists for each branch
crossed_outputs = []

# CROSSED DATA INPUT
input_crossed = Input(shape=(X_train_crossed.shape[1],), dtype='int64', name='wide_inputs')
for idx,col in enumerate(cross_col_df_names):
    
    # track what the maximum integer value will be for this variable
    # which is the same as the number of categories
    N = max(df_train[col].max(),df_test[col].max())+1
    N = len(encoders[col].classes_)
    N_reduced = int(np.sqrt(N))
    
    
    # this line of code does this: input_branch[:,idx]
    x = tf.gather(input_crossed, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=N_reduced, 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs to concatenate later
    crossed_outputs.append(x)
    

# now concatenate the outputs and add a fully connected layer
wide_branch = concatenate(crossed_outputs, name='wide_concat')

# reset this input branch
all_deep_branch_outputs = []


# CATEGORICAL DATA INPUT
input_cat = Input(shape=(X_train_cat.shape[1],), dtype='int64', name='categorical_input')
for idx,col in enumerate(categorical_headers_ints):
    
    # track what the maximum integer value will be for this variable
    # which is the same as the number of categories
    N = max(df_train[col].max(),df_test[col].max())+1
    N_reduced = int(np.sqrt(N))
    
    # this line of code does this: input_branch[:,idx]
    x = tf.gather(input_cat, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=N_reduced, 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs to concatenate later
    all_deep_branch_outputs.append(x)
    
# NUMERIC DATA INPUT
# create dense input branch for numeric
input_num = Input(shape=(X_train_num.shape[1],), name='numeric')
x_dense = Dense(units=20, activation='relu',name='num_1')(input_num)
    
all_deep_branch_outputs.append(x_dense)


# merge the deep branches together
deep_branch = concatenate(all_deep_branch_outputs,name='concat_embeds')
deep_branch = Dense(units=50,activation='relu', name='deep1')(deep_branch)
deep_branch = Dense(units=25,activation='relu', name='deep2')(deep_branch)
deep_branch = Dense(units=10,activation='relu', name='deep3')(deep_branch)
    
# merge the deep and wide branch
final_branch = concatenate([wide_branch, deep_branch],
                           name='concat_deep_wide')
final_branch = Dense(units=1,activation='sigmoid',
                     name='combined')(final_branch)

model = Model(inputs=[input_crossed,input_cat,input_num], 
              outputs=final_branch)

# %%
# Add precision as a performance metric
precision = tf.keras.metrics.Precision()

# %%
from tensorflow.keras.utils import plot_model

plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# %%time

model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['accuracy', precision])

# lets also add the history variable to see how we are doing
# and lets add a validation set to keep track of our progress
history = model.fit([X_train_crossed,X_train_cat,X_train_num],
                    y_train, 
                    epochs=15, 
                    batch_size=32, 
                    verbose=1, 
                    validation_data = ([X_test_crossed,X_test_cat,X_test_num],y_test))

yhat = np.round(model.predict([X_test_crossed,X_test_cat,X_test_num]))
print(mt.confusion_matrix(y_test,yhat))
print(mt.classification_report(y_test,yhat))
# Out:
# Epoch 1/15
# 285/285 [==============================] - 2s 3ms/step - loss: 0.1057 - accuracy: 0.8648 - precision: 0.8870 - val_loss: 0.0776 - val_accuracy: 0.8972 - val_precision: 0.9163
# Epoch 2/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0635 - accuracy: 0.9166 - precision: 0.9318 - val_loss: 0.0638 - val_accuracy: 0.9091 - val_precision: 0.9220
# Epoch 3/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0552 - accuracy: 0.9259 - precision: 0.9403 - val_loss: 0.0547 - val_accuracy: 0.9289 - val_precision: 0.9420
# Epoch 4/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0506 - accuracy: 0.9332 - precision: 0.9482 - val_loss: 0.0511 - val_accuracy: 0.9289 - val_precision: 0.9342
# Epoch 5/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0469 - accuracy: 0.9386 - precision: 0.9529 - val_loss: 0.0574 - val_accuracy: 0.9259 - val_precision: 0.9263
# Epoch 6/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0452 - accuracy: 0.9408 - precision: 0.9544 - val_loss: 0.0461 - val_accuracy: 0.9417 - val_precision: 0.9469
# Epoch 7/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0427 - accuracy: 0.9435 - precision: 0.9574 - val_loss: 0.0544 - val_accuracy: 0.9308 - val_precision: 0.9305
# Epoch 8/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0417 - accuracy: 0.9456 - precision: 0.9599 - val_loss: 0.0457 - val_accuracy: 0.9417 - val_precision: 0.9562
# Epoch 9/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0397 - accuracy: 0.9485 - precision: 0.9619 - val_loss: 0.0495 - val_accuracy: 0.9338 - val_precision: 0.9345
# Epoch 10/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0393 - accuracy: 0.9494 - precision: 0.9618 - val_loss: 0.0466 - val_accuracy: 0.9397 - val_precision: 0.9438
# Epoch 11/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0380 - accuracy: 0.9513 - precision: 0.9638 - val_loss: 0.0522 - val_accuracy: 0.9308 - val_precision: 0.9286
# Epoch 12/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0369 - accuracy: 0.9532 - precision: 0.9645 - val_loss: 0.0445 - val_accuracy: 0.9427 - val_precision: 0.9500
# Epoch 13/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0362 - accuracy: 0.9544 - precision: 0.9651 - val_loss: 0.0434 - val_accuracy: 0.9407 - val_precision: 0.9509
# Epoch 14/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0353 - accuracy: 0.9537 - precision: 0.9660 - val_loss: 0.0466 - val_accuracy: 0.9377 - val_precision: 0.9456
# Epoch 15/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0350 - accuracy: 0.9546 - precision: 0.9668 - val_loss: 0.0511 - val_accuracy: 0.9328 - val_precision: 0.9316
# 32/32 [==============================] - 0s 1ms/step
# [[100  62]
#  [  6 844]]
#               precision    recall  f1-score   support
#
#            0       0.94      0.62      0.75       162
#            1       0.93      0.99      0.96       850
#
#     accuracy                           0.93      1012
#    macro avg       0.94      0.81      0.85      1012
# weighted avg       0.93      0.93      0.93      1012
#
# Wall time: 11.2 s

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'precision', 'val_loss', 'val_accuracy', 'val_precision'])

# %%
from matplotlib import pyplot as plt

# %matplotlib inline

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training','Validation'])
plt.ylabel('Accuracy %')
plt.xlabel('epochs')
plt.ylim([0.8,1])

plt.subplot(2,1,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training','Validation'])
plt.ylabel('Loss')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
# %matplotlib inline

plt.figure(figsize=(10,4))
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.legend(['Training','Validation'])
plt.ylabel('Precision')
plt.xlabel('epochs')
plt.ylim([0.8,1])
# Out:
# (0.8, 1.0)

# %% [markdown]
# ## Deep and Wide Network #2

# %%
cross_columns = [['Education_Level', 'Income_Category','Gender', 'Marital_Status']]

# cross each set of columns in the list above
cross_col_df_names = []
for cols_list in cross_columns:
    # encode as ints for the embedding
    enc = LabelEncoder()
    
    # 1. create crossed labels by join operation
    X_crossed_train = df_train[cols_list].apply(lambda x: '_'.join(x), axis=1)
    X_crossed_test = df_test[cols_list].apply(lambda x: '_'.join(x), axis=1)
    
    # get a nice name for this new crossed column
    cross_col_name = '_'.join(cols_list)
    
    # 2. encode as integers, stacking all possibilities
    enc.fit(np.hstack((X_crossed_train.to_numpy(),  X_crossed_test.to_numpy())))
    
    # 3. Save into dataframe with new name
    df_train[cross_col_name] = enc.transform(X_crossed_train)
    df_test[cross_col_name] = enc.transform(X_crossed_test)
    
    # Save the encoder used here for later:
    encoders[cross_col_name] = enc
    
    # keep track of the new names of the crossed columns
    cross_col_df_names.append(cross_col_name) 
    
cross_col_df_names
# Out:
# ['Education_Level_Income_Category_Gender_Marital_Status']

# %%
# get crossed columns
X_train_crossed = df_train[cross_col_df_names].to_numpy()
X_test_crossed = df_test[cross_col_df_names].to_numpy()

# save categorical features
X_train_cat = df_train[categorical_headers_ints].to_numpy() 
X_test_cat = df_test[categorical_headers_ints].to_numpy() 

# and save off the numeric features
X_train_num =  df_train[numeric_headers].to_numpy()
X_test_num = df_test[numeric_headers].to_numpy()


# we need to create separate lists for each branch
crossed_outputs = []

# CROSSED DATA INPUT
input_crossed = Input(shape=(X_train_crossed.shape[1],), dtype='int64', name='wide_inputs')
for idx,col in enumerate(cross_col_df_names):
    
    # track what the maximum integer value will be for this variable
    # which is the same as the number of categories
    N = max(df_train[col].max(),df_test[col].max())+1
    N = len(encoders[col].classes_)
    N_reduced = int(np.sqrt(N))
    
    
    # this line of code does this: input_branch[:,idx]
    x = tf.gather(input_crossed, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=N_reduced, 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs to concatenate later
    crossed_outputs.append(x)
    

# now concatenate the outputs and add a fully connected layer
wide_branch = concatenate(crossed_outputs, name='wide_concat')

# reset this input branch
all_deep_branch_outputs = []


# CATEGORICAL DATA INPUT
input_cat = Input(shape=(X_train_cat.shape[1],), dtype='int64', name='categorical_input')
for idx,col in enumerate(categorical_headers_ints):
    
    # track what the maximum integer value will be for this variable
    # which is the same as the number of categories
    N = max(df_train[col].max(),df_test[col].max())+1
    N_reduced = int(np.sqrt(N))
    
    # this line of code does this: input_branch[:,idx]
    x = tf.gather(input_cat, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=N_reduced, 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs to concatenate later
    all_deep_branch_outputs.append(x)
    
# NUMERIC DATA INPUT
# create dense input branch for numeric
input_num = Input(shape=(X_train_num.shape[1],), name='numeric')
x_dense = Dense(units=20, activation='relu',name='num_1')(input_num)
    
all_deep_branch_outputs.append(x_dense)


# merge the deep branches together
deep_branch = concatenate(all_deep_branch_outputs,name='concat_embeds')
deep_branch = Dense(units=50,activation='relu', name='deep1')(deep_branch)
deep_branch = Dense(units=25,activation='relu', name='deep2')(deep_branch)
deep_branch = Dense(units=10,activation='relu', name='deep3')(deep_branch)
    
# merge the deep and wide branch
final_branch = concatenate([wide_branch, deep_branch],
                           name='concat_deep_wide')
final_branch = Dense(units=1,activation='sigmoid',
                     name='combined')(final_branch)

model = Model(inputs=[input_crossed,input_cat,input_num], 
              outputs=final_branch)

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# %%time

model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['accuracy',precision])

# lets also add the history variable to see how we are doing
# and lets add a validation set to keep track of our progress
history = model.fit([X_train_crossed,X_train_cat,X_train_num],
                    y_train, 
                    epochs=15, 
                    batch_size=32, 
                    verbose=1, 
                    validation_data = ([X_test_crossed,X_test_cat,X_test_num],y_test))

yhat = np.round(model.predict([X_test_crossed,X_test_cat,X_test_num]))
print(mt.confusion_matrix(y_test,yhat))
print(mt.classification_report(y_test,yhat))
# Out:
# Epoch 1/15
# 285/285 [==============================] - 2s 3ms/step - loss: 0.0979 - accuracy: 0.8839 - precision: 0.8981 - val_loss: 0.0815 - val_accuracy: 0.8982 - val_precision: 0.9136
# Epoch 2/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0705 - accuracy: 0.9100 - precision: 0.9271 - val_loss: 0.0737 - val_accuracy: 0.9002 - val_precision: 0.9102
# Epoch 3/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0618 - accuracy: 0.9220 - precision: 0.9369 - val_loss: 0.0584 - val_accuracy: 0.9180 - val_precision: 0.9343
# Epoch 4/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0554 - accuracy: 0.9286 - precision: 0.9430 - val_loss: 0.0573 - val_accuracy: 0.9229 - val_precision: 0.9308
# Epoch 5/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0519 - accuracy: 0.9320 - precision: 0.9470 - val_loss: 0.0500 - val_accuracy: 0.9318 - val_precision: 0.9514
# Epoch 6/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0490 - accuracy: 0.9367 - precision: 0.9518 - val_loss: 0.0484 - val_accuracy: 0.9318 - val_precision: 0.9557
# Epoch 7/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0464 - accuracy: 0.9399 - precision: 0.9553 - val_loss: 0.0508 - val_accuracy: 0.9298 - val_precision: 0.9401
# Epoch 8/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0453 - accuracy: 0.9406 - precision: 0.9556 - val_loss: 0.0469 - val_accuracy: 0.9397 - val_precision: 0.9519
# Epoch 9/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0423 - accuracy: 0.9460 - precision: 0.9605 - val_loss: 0.0473 - val_accuracy: 0.9377 - val_precision: 0.9549
# Epoch 10/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0407 - accuracy: 0.9478 - precision: 0.9615 - val_loss: 0.0504 - val_accuracy: 0.9348 - val_precision: 0.9414
# Epoch 11/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0397 - accuracy: 0.9496 - precision: 0.9633 - val_loss: 0.0484 - val_accuracy: 0.9328 - val_precision: 0.9525
# Epoch 12/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0381 - accuracy: 0.9506 - precision: 0.9646 - val_loss: 0.0468 - val_accuracy: 0.9348 - val_precision: 0.9485
# Epoch 13/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0368 - accuracy: 0.9534 - precision: 0.9662 - val_loss: 0.0486 - val_accuracy: 0.9348 - val_precision: 0.9465
# Epoch 14/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0359 - accuracy: 0.9551 - precision: 0.9688 - val_loss: 0.0489 - val_accuracy: 0.9387 - val_precision: 0.9477
# Epoch 15/15
# 285/285 [==============================] - 1s 2ms/step - loss: 0.0353 - accuracy: 0.9558 - precision: 0.9679 - val_loss: 0.0483 - val_accuracy: 0.9368 - val_precision: 0.9517
# 32/32 [==============================] - 0s 1ms/step
# [[120  42]
#  [ 22 828]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.74      0.79       162
#            1       0.95      0.97      0.96       850
#
#     accuracy                           0.94      1012
#    macro avg       0.90      0.86      0.88      1012
# weighted avg       0.93      0.94      0.94      1012
#
# Wall time: 11.2 s

# %%
# %matplotlib inline

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training','Validation'])
plt.ylabel('Accuracy %')
plt.xlabel('epochs')
plt.ylim([0.8,1])

plt.subplot(2,1,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training','Validation'])
plt.ylabel('Loss')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
# %matplotlib inline

plt.figure(figsize=(10,4))
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.legend(['Training','Validation'])
plt.ylabel('Precision')
plt.xlabel('epochs')
plt.ylim([0.8,1])
# Out:
# (0.8, 1.0)

# %% [markdown]
# ## Deep and Wide Network #3

# %%
cross_columns = [['Education_Level', 'Income_Category','Gender', 'Marital_Status']]

# cross each set of columns in the list above
cross_col_df_names = []
for cols_list in cross_columns:
    # encode as ints for the embedding
    enc = LabelEncoder()
    
    # 1. create crossed labels by join operation
    X_crossed_train = df_train[cols_list].apply(lambda x: '_'.join(x), axis=1)
    X_crossed_test = df_test[cols_list].apply(lambda x: '_'.join(x), axis=1)
    
    # get a nice name for this new crossed column
    cross_col_name = '_'.join(cols_list)
    
    # 2. encode as integers, stacking all possibilities
    enc.fit(np.hstack((X_crossed_train.to_numpy(),  X_crossed_test.to_numpy())))
    
    # 3. Save into dataframe with new name
    df_train[cross_col_name] = enc.transform(X_crossed_train)
    df_test[cross_col_name] = enc.transform(X_crossed_test)
    
    # Save the encoder used here for later:
    encoders[cross_col_name] = enc
    
    # keep track of the new names of the crossed columns
    cross_col_df_names.append(cross_col_name) 
    
cross_col_df_names
# Out:
# ['Education_Level_Income_Category_Gender_Marital_Status']

# %%
# get crossed columns
X_train_crossed = df_train[cross_col_df_names].to_numpy()
X_test_crossed = df_test[cross_col_df_names].to_numpy()

# save categorical features
X_train_cat = df_train[categorical_headers_ints].to_numpy() 
X_test_cat = df_test[categorical_headers_ints].to_numpy() 

# and save off the numeric features
X_train_num =  df_train[numeric_headers].to_numpy()
X_test_num = df_test[numeric_headers].to_numpy()


# we need to create separate lists for each branch
crossed_outputs = []

# CROSSED DATA INPUT
input_crossed = Input(shape=(X_train_crossed.shape[1],), dtype='int64', name='wide_inputs')
for idx,col in enumerate(cross_col_df_names):
    
    # track what the maximum integer value will be for this variable
    # which is the same as the number of categories
    N = max(df_train[col].max(),df_test[col].max())+1
    N = len(encoders[col].classes_)
    N_reduced = int(np.sqrt(N))
    
    
    # this line of code does this: input_branch[:,idx]
    x = tf.gather(input_crossed, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=N_reduced, 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs to concatenate later
    crossed_outputs.append(x)
    

# now concatenate the outputs and add a fully connected layer
wide_branch = concatenate(crossed_outputs, name='wide_concat')

# reset this input branch
all_deep_branch_outputs = []


# CATEGORICAL DATA INPUT
input_cat = Input(shape=(X_train_cat.shape[1],), dtype='int64', name='categorical_input')
for idx,col in enumerate(categorical_headers_ints):
    
    # track what the maximum integer value will be for this variable
    # which is the same as the number of categories
    N = max(df_train[col].max(),df_test[col].max())+1
    N_reduced = int(np.sqrt(N))
    
    # this line of code does this: input_branch[:,idx]
    x = tf.gather(input_cat, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=N_reduced, 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs to concatenate later
    all_deep_branch_outputs.append(x)
    
# NUMERIC DATA INPUT
# create dense input branch for numeric
input_num = Input(shape=(X_train_num.shape[1],), name='numeric')
x_dense = Dense(units=20, activation='relu',name='num_1')(input_num)
    
all_deep_branch_outputs.append(x_dense)


# merge the deep branches together
deep_branch = concatenate(all_deep_branch_outputs,name='concat_embeds')
deep_branch = Dense(units=500,activation='relu', name='deep1')(deep_branch)
deep_branch = Dense(units=250,activation='relu', name='deep2')(deep_branch)
deep_branch = Dense(units=100,activation='relu', name='deep3')(deep_branch)
    
# merge the deep and wide branch
final_branch = concatenate([wide_branch, deep_branch],
                           name='concat_deep_wide')
final_branch = Dense(units=1,activation='sigmoid',
                     name='combined')(final_branch)

model = Model(inputs=[input_crossed,input_cat,input_num], 
              outputs=final_branch)

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# %%time

model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['accuracy',precision])

# lets also add the history variable to see how we are doing
# and lets add a validation set to keep track of our progress
history = model.fit([X_train_crossed,X_train_cat,X_train_num],
                    y_train, 
                    epochs=15, 
                    batch_size=32, 
                    verbose=1, 
                    validation_data = ([X_test_crossed,X_test_cat,X_test_num],y_test))

yhat = np.round(model.predict([X_test_crossed,X_test_cat,X_test_num]))
print(mt.confusion_matrix(y_test,yhat))
print(mt.classification_report(y_test,yhat))
# Out:
# Epoch 1/15
# 285/285 [==============================] - 2s 4ms/step - loss: 0.0843 - accuracy: 0.8900 - precision: 0.9141 - val_loss: 0.0703 - val_accuracy: 0.9061 - val_precision: 0.9117
# Epoch 2/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0574 - accuracy: 0.9233 - precision: 0.9406 - val_loss: 0.0555 - val_accuracy: 0.9180 - val_precision: 0.9383
# Epoch 3/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0492 - accuracy: 0.9347 - precision: 0.9498 - val_loss: 0.0508 - val_accuracy: 0.9308 - val_precision: 0.9472
# Epoch 4/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0449 - accuracy: 0.9410 - precision: 0.9548 - val_loss: 0.0491 - val_accuracy: 0.9298 - val_precision: 0.9421
# Epoch 5/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0410 - accuracy: 0.9483 - precision: 0.9597 - val_loss: 0.0476 - val_accuracy: 0.9308 - val_precision: 0.9452
# Epoch 6/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0383 - accuracy: 0.9493 - precision: 0.9617 - val_loss: 0.0485 - val_accuracy: 0.9308 - val_precision: 0.9462
# Epoch 7/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0361 - accuracy: 0.9535 - precision: 0.9657 - val_loss: 0.0502 - val_accuracy: 0.9298 - val_precision: 0.9401
# Epoch 8/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0353 - accuracy: 0.9534 - precision: 0.9659 - val_loss: 0.0498 - val_accuracy: 0.9318 - val_precision: 0.9393
# Epoch 9/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0305 - accuracy: 0.9617 - precision: 0.9717 - val_loss: 0.0502 - val_accuracy: 0.9377 - val_precision: 0.9497
# Epoch 10/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0291 - accuracy: 0.9646 - precision: 0.9733 - val_loss: 0.0523 - val_accuracy: 0.9308 - val_precision: 0.9535
# Epoch 11/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0290 - accuracy: 0.9625 - precision: 0.9727 - val_loss: 0.0530 - val_accuracy: 0.9269 - val_precision: 0.9389
# Epoch 12/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0259 - accuracy: 0.9676 - precision: 0.9756 - val_loss: 0.0483 - val_accuracy: 0.9387 - val_precision: 0.9518
# Epoch 13/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0236 - accuracy: 0.9717 - precision: 0.9784 - val_loss: 0.0530 - val_accuracy: 0.9348 - val_precision: 0.9444
# Epoch 14/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0234 - accuracy: 0.9721 - precision: 0.9789 - val_loss: 0.0488 - val_accuracy: 0.9387 - val_precision: 0.9581
# Epoch 15/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0222 - accuracy: 0.9729 - precision: 0.9808 - val_loss: 0.0538 - val_accuracy: 0.9289 - val_precision: 0.9361
# 32/32 [==============================] - 0s 2ms/step
# [[105  57]
#  [ 15 835]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.65      0.74       162
#            1       0.94      0.98      0.96       850
#
#     accuracy                           0.93      1012
#    macro avg       0.91      0.82      0.85      1012
# weighted avg       0.93      0.93      0.92      1012
#
# Wall time: 16.4 s

# %%
# %matplotlib inline

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training','Validation'])
plt.ylabel('Accuracy %')
plt.xlabel('epochs')
plt.ylim([0.8,1])

plt.subplot(2,1,2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training','Validation'])
plt.ylabel('Loss')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
# %matplotlib inline

plt.figure(figsize=(10,4))
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.legend(['Training','Validation'])
plt.ylabel('Precision')
plt.xlabel('epochs')
plt.ylim([0.8,1])
# Out:
# (0.8, 1.0)

# %% [markdown]
# ### Altered Model 1: 5 Layers

# %%
# now concatenate the outputs and add a fully connected layer
wide_branch = concatenate(crossed_outputs, name='wide_concat')

# reset this input branch
all_deep_branch_outputs = []


# CATEGORICAL DATA INPUT
input_cat = Input(shape=(X_train_cat.shape[1],), dtype='int64', name='categorical_input')
for idx,col in enumerate(categorical_headers_ints):
    
    # track what the maximum integer value will be for this variable
    # which is the same as the number of categories
    N = max(df_train[col].max(),df_test[col].max())+1
    N_reduced = int(np.sqrt(N))
    
    # this line of code does this: input_branch[:,idx]
    x = tf.gather(input_cat, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=N_reduced, 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs to concatenate later
    all_deep_branch_outputs.append(x)
    
# NUMERIC DATA INPUT
# create dense input branch for numeric
input_num = Input(shape=(X_train_num.shape[1],), name='numeric')
x_dense = Dense(units=20, activation='relu',name='num_1')(input_num)
    
all_deep_branch_outputs.append(x_dense)


# merge the deep branches together
deep_branch = concatenate(all_deep_branch_outputs,name='concat_embeds')
deep_branch = Dense(units=500,activation='relu', name='deep1')(deep_branch)
deep_branch = Dense(units=250,activation='relu', name='deep2')(deep_branch)
deep_branch = Dense(units=100,activation='relu', name='deep3')(deep_branch)
deep_branch = Dense(units=50,activation='relu', name='deep4')(deep_branch)
deep_branch = Dense(units=25,activation='relu', name='deep5')(deep_branch)
    
# merge the deep and wide branch
final_branch = concatenate([wide_branch, deep_branch],
                           name='concat_deep_wide')
final_branch = Dense(units=1,activation='sigmoid',
                     name='combined')(final_branch)

model = Model(inputs=[input_crossed,input_cat,input_num], 
              outputs=final_branch)

# %%
from tensorflow.keras.utils import plot_model

plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
# %%time

model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['accuracy',precision])

# lets also add the history variable to see how we are doing
# and lets add a validation set to keep track of our progress
history1 = model.fit([X_train_crossed,X_train_cat,X_train_num],
                    y_train, 
                    epochs=15, 
                    batch_size=32, 
                    verbose=1, 
                    validation_data = ([X_test_crossed,X_test_cat,X_test_num],y_test))

yhat = np.round(model.predict([X_test_crossed,X_test_cat,X_test_num]))
print(mt.confusion_matrix(y_test,yhat))
print(mt.classification_report(y_test,yhat))
# Out:
# Epoch 1/15
# 285/285 [==============================] - 3s 5ms/step - loss: 0.0847 - accuracy: 0.8894 - precision: 0.9100 - val_loss: 0.0731 - val_accuracy: 0.9061 - val_precision: 0.9135
# Epoch 2/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0629 - accuracy: 0.9182 - precision: 0.9348 - val_loss: 0.0776 - val_accuracy: 0.9022 - val_precision: 0.9007
# Epoch 3/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0540 - accuracy: 0.9274 - precision: 0.9433 - val_loss: 0.0563 - val_accuracy: 0.9259 - val_precision: 0.9429
# Epoch 4/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0477 - accuracy: 0.9361 - precision: 0.9509 - val_loss: 0.0592 - val_accuracy: 0.9249 - val_precision: 0.9243
# Epoch 5/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0437 - accuracy: 0.9421 - precision: 0.9551 - val_loss: 0.0514 - val_accuracy: 0.9269 - val_precision: 0.9543
# Epoch 6/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0417 - accuracy: 0.9449 - precision: 0.9586 - val_loss: 0.0525 - val_accuracy: 0.9289 - val_precision: 0.9555
# Epoch 7/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0384 - accuracy: 0.9513 - precision: 0.9635 - val_loss: 0.0552 - val_accuracy: 0.9289 - val_precision: 0.9332
# Epoch 8/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0366 - accuracy: 0.9527 - precision: 0.9640 - val_loss: 0.0565 - val_accuracy: 0.9239 - val_precision: 0.9271
# Epoch 9/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0339 - accuracy: 0.9581 - precision: 0.9683 - val_loss: 0.0512 - val_accuracy: 0.9348 - val_precision: 0.9465
# Epoch 10/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0329 - accuracy: 0.9591 - precision: 0.9702 - val_loss: 0.0478 - val_accuracy: 0.9368 - val_precision: 0.9497
# Epoch 11/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0305 - accuracy: 0.9604 - precision: 0.9706 - val_loss: 0.0486 - val_accuracy: 0.9328 - val_precision: 0.9474
# Epoch 12/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0281 - accuracy: 0.9653 - precision: 0.9740 - val_loss: 0.0535 - val_accuracy: 0.9249 - val_precision: 0.9339
# Epoch 13/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0270 - accuracy: 0.9675 - precision: 0.9760 - val_loss: 0.0555 - val_accuracy: 0.9289 - val_precision: 0.9381
# Epoch 14/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0251 - accuracy: 0.9691 - precision: 0.9773 - val_loss: 0.0555 - val_accuracy: 0.9289 - val_precision: 0.9371
# Epoch 15/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0243 - accuracy: 0.9702 - precision: 0.9774 - val_loss: 0.0493 - val_accuracy: 0.9338 - val_precision: 0.9568
# 32/32 [==============================] - 0s 2ms/step
# [[125  37]
#  [ 30 820]]
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79       162
#            1       0.96      0.96      0.96       850
#
#     accuracy                           0.93      1012
#    macro avg       0.88      0.87      0.87      1012
# weighted avg       0.93      0.93      0.93      1012
#
# Wall time: 17.2 s

# %%
# %matplotlib inline

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.legend(['Training','Validation'])
plt.ylabel('Accuracy %')
plt.xlabel('epochs')
plt.ylim([0.8,1])

plt.subplot(2,1,2)
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.legend(['Training','Validation'])
plt.ylabel('Loss')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
# %matplotlib inline

plt.figure(figsize=(10,4))
plt.plot(history1.history['precision'])
plt.plot(history1.history['val_precision'])
plt.legend(['Training','Validation'])
plt.ylabel('Precision')
plt.xlabel('epochs')
plt.ylim([0.8,1])
# Out:
# (0.8, 1.0)

# %% [markdown]
# ### Altered Model 2: 2 Layers

# %%
# merge the deep branches together
deep_branch = concatenate(all_deep_branch_outputs,name='concat_embeds')
deep_branch = Dense(units=500,activation='relu', name='deep1')(deep_branch)
deep_branch = Dense(units=250,activation='relu', name='deep2')(deep_branch)
    
# merge the deep and wide branch
final_branch = concatenate([wide_branch, deep_branch],
                           name='concat_deep_wide')
final_branch = Dense(units=1,activation='sigmoid',
                     name='combined')(final_branch)

model = Model(inputs=[input_crossed,input_cat,input_num], 
              outputs=final_branch)


model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['accuracy',precision])

# lets also add the history variable to see how we are doing
# and lets add a validation set to keep track of our progress
history2 = model.fit([X_train_crossed,X_train_cat,X_train_num],
                    y_train, 
                    epochs=15, 
                    batch_size=32, 
                    verbose=1, 
                    validation_data = ([X_test_crossed,X_test_cat,X_test_num],y_test))

yhat = np.round(model.predict([X_test_crossed,X_test_cat,X_test_num]))
print(mt.confusion_matrix(y_test,yhat))
print(mt.classification_report(y_test,yhat))
# Out:
# Epoch 1/15
# 285/285 [==============================] - 3s 5ms/step - loss: 0.0582 - accuracy: 0.9206 - precision: 0.9393 - val_loss: 0.0464 - val_accuracy: 0.9377 - val_precision: 0.9416
# Epoch 2/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0420 - accuracy: 0.9450 - precision: 0.9603 - val_loss: 0.0516 - val_accuracy: 0.9298 - val_precision: 0.9323
# Epoch 3/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0369 - accuracy: 0.9530 - precision: 0.9652 - val_loss: 0.0467 - val_accuracy: 0.9397 - val_precision: 0.9488
# Epoch 4/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0341 - accuracy: 0.9564 - precision: 0.9691 - val_loss: 0.0486 - val_accuracy: 0.9269 - val_precision: 0.9565
# Epoch 5/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0314 - accuracy: 0.9604 - precision: 0.9704 - val_loss: 0.0427 - val_accuracy: 0.9377 - val_precision: 0.9549
# Epoch 6/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0281 - accuracy: 0.9638 - precision: 0.9736 - val_loss: 0.0444 - val_accuracy: 0.9457 - val_precision: 0.9553
# Epoch 7/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0267 - accuracy: 0.9673 - precision: 0.9753 - val_loss: 0.0494 - val_accuracy: 0.9328 - val_precision: 0.9443
# Epoch 8/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0258 - accuracy: 0.9677 - precision: 0.9775 - val_loss: 0.0448 - val_accuracy: 0.9397 - val_precision: 0.9540
# Epoch 9/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0242 - accuracy: 0.9696 - precision: 0.9787 - val_loss: 0.0478 - val_accuracy: 0.9318 - val_precision: 0.9483
# Epoch 10/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0210 - accuracy: 0.9754 - precision: 0.9815 - val_loss: 0.0448 - val_accuracy: 0.9397 - val_precision: 0.9561
# Epoch 11/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0200 - accuracy: 0.9756 - precision: 0.9817 - val_loss: 0.0434 - val_accuracy: 0.9447 - val_precision: 0.9553
# Epoch 12/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0192 - accuracy: 0.9783 - precision: 0.9835 - val_loss: 0.0478 - val_accuracy: 0.9387 - val_precision: 0.9477
# Epoch 13/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0178 - accuracy: 0.9800 - precision: 0.9844 - val_loss: 0.0489 - val_accuracy: 0.9358 - val_precision: 0.9591
# Epoch 14/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0173 - accuracy: 0.9796 - precision: 0.9857 - val_loss: 0.0514 - val_accuracy: 0.9348 - val_precision: 0.9527
# Epoch 15/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0171 - accuracy: 0.9785 - precision: 0.9849 - val_loss: 0.0485 - val_accuracy: 0.9397 - val_precision: 0.9478
# 32/32 [==============================] - 0s 2ms/step
# [[116  46]
#  [ 15 835]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.72      0.79       162
#            1       0.95      0.98      0.96       850
#
#     accuracy                           0.94      1012
#    macro avg       0.92      0.85      0.88      1012
# weighted avg       0.94      0.94      0.94      1012

# %%
# %matplotlib inline

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.legend(['Training','Validation'])
plt.ylabel('Accuracy %')
plt.xlabel('epochs')
plt.ylim([0.8,1])

plt.subplot(2,1,2)
plt.plot(history2.history['loss'])
plt.plot(history2.history['val_loss'])
plt.legend(['Training','Validation'])
plt.ylabel('Loss')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
# %matplotlib inline

plt.figure(figsize=(10,4))
plt.plot(history2.history['precision'])
plt.plot(history2.history['val_precision'])
plt.legend(['Training','Validation'])
plt.ylabel('Precision')
plt.xlabel('epochs')
plt.ylim([0.8,1])
# Out:
# (0.8, 1.0)

# %% [markdown]
# ### Comparison to Model Without Wide Branch

# %%
# merge the deep branches together
deep_branch = concatenate(all_deep_branch_outputs,name='concat_embeds')
deep_branch = Dense(units=500,activation='relu', name='deep1')(deep_branch)
deep_branch = Dense(units=250,activation='relu', name='deep2')(deep_branch)
deep_branch = Dense(units=100,activation='relu', name='deep3')(deep_branch)
deep_branch = Dense(units=50,activation='relu', name='deep4')(deep_branch)
deep_branch = Dense(units=25,activation='relu', name='deep5')(deep_branch)
    
# merge the deep and wide branch
final_branch = concatenate([deep_branch],
                           name='deep')
final_branch = Dense(units=1,activation='sigmoid',
                     name='combined')(final_branch)

model = Model(inputs=[input_crossed,input_cat,input_num], 
              outputs=final_branch)


model.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['accuracy',precision])

# lets also add the history variable to see how we are doing
# and lets add a validation set to keep track of our progress
history3 = model.fit([X_train_crossed,X_train_cat,X_train_num],
                    y_train, 
                    epochs=15, 
                    batch_size=32, 
                    verbose=1, 
                    validation_data = ([X_test_crossed,X_test_cat,X_test_num],y_test))

yhat = np.round(model.predict([X_test_crossed,X_test_cat,X_test_num]))
print(mt.confusion_matrix(y_test,yhat))
print(mt.classification_report(y_test,yhat))
# Out:
# Epoch 1/15
# 285/285 [==============================] - 3s 4ms/step - loss: 0.0583 - accuracy: 0.9251 - precision: 0.9386 - val_loss: 0.0424 - val_accuracy: 0.9447 - val_precision: 0.9542
# Epoch 2/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0402 - accuracy: 0.9461 - precision: 0.9585 - val_loss: 0.0394 - val_accuracy: 0.9447 - val_precision: 0.9511
# Epoch 3/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0356 - accuracy: 0.9537 - precision: 0.9666 - val_loss: 0.0407 - val_accuracy: 0.9447 - val_precision: 0.9584
# Epoch 4/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0321 - accuracy: 0.9586 - precision: 0.9715 - val_loss: 0.0407 - val_accuracy: 0.9476 - val_precision: 0.9586
# Epoch 5/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0298 - accuracy: 0.9617 - precision: 0.9710 - val_loss: 0.0329 - val_accuracy: 0.9575 - val_precision: 0.9622
# Epoch 6/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0259 - accuracy: 0.9679 - precision: 0.9773 - val_loss: 0.0399 - val_accuracy: 0.9526 - val_precision: 0.9567
# Epoch 7/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0253 - accuracy: 0.9682 - precision: 0.9769 - val_loss: 0.0380 - val_accuracy: 0.9516 - val_precision: 0.9609
# Epoch 8/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0251 - accuracy: 0.9685 - precision: 0.9771 - val_loss: 0.0354 - val_accuracy: 0.9526 - val_precision: 0.9557
# Epoch 9/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0223 - accuracy: 0.9725 - precision: 0.9805 - val_loss: 0.0392 - val_accuracy: 0.9486 - val_precision: 0.9586
# Epoch 10/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0218 - accuracy: 0.9733 - precision: 0.9813 - val_loss: 0.0365 - val_accuracy: 0.9565 - val_precision: 0.9664
# Epoch 11/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0192 - accuracy: 0.9754 - precision: 0.9822 - val_loss: 0.0383 - val_accuracy: 0.9516 - val_precision: 0.9609
# Epoch 12/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0180 - accuracy: 0.9779 - precision: 0.9835 - val_loss: 0.0431 - val_accuracy: 0.9486 - val_precision: 0.9493
# Epoch 13/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0193 - accuracy: 0.9769 - precision: 0.9834 - val_loss: 0.0438 - val_accuracy: 0.9457 - val_precision: 0.9671
# Epoch 14/15
# 285/285 [==============================] - 1s 3ms/step - loss: 0.0192 - accuracy: 0.9769 - precision: 0.9836 - val_loss: 0.0407 - val_accuracy: 0.9486 - val_precision: 0.9672
# Epoch 15/15
# 285/285 [==============================] - 1s 4ms/step - loss: 0.0162 - accuracy: 0.9808 - precision: 0.9853 - val_loss: 0.0412 - val_accuracy: 0.9476 - val_precision: 0.9565
# 32/32 [==============================] - 0s 2ms/step
# [[124  38]
#  [ 15 835]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.77      0.82       162
#            1       0.96      0.98      0.97       850
#
#     accuracy                           0.95      1012
#    macro avg       0.92      0.87      0.90      1012
# weighted avg       0.95      0.95      0.95      1012

# %%
# %matplotlib inline

plt.figure(figsize=(10,4))
plt.subplot(2,2,1)
plt.plot(history1.history['accuracy'])
plt.plot(history3.history['accuracy'])
plt.legend(['Wide & Deep Branch','Deep Branch'])
plt.ylim([0.8,1])

plt.ylabel('Accuracy %')
plt.title('Training')
plt.subplot(2,2,2)
plt.plot(history1.history['val_accuracy'])
plt.plot(history3.history['val_accuracy'])
plt.legend(['Wide & Deep Branch','Deep Branch'])
plt.title('Validation')
plt.ylim([0.8,1])

plt.subplot(2,2,3)
plt.plot(history1.history['loss'])
plt.plot(history3.history['loss'])
plt.legend(['Wide & Deep Branch','Deep Branch'])
plt.ylabel('Training Loss')
plt.xlabel('epochs')
plt.ylim([0,0.25])

plt.subplot(2,2,4)
plt.plot(history1.history['val_loss'])
plt.plot(history3.history['val_loss'])
plt.legend(['Wide & Deep Branch','Deep Branch'])
plt.xlabel('epochs')
plt.ylim([0,0.25])
# Out:
# (0.0, 0.25)

# %%
# %matplotlib inline

plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.plot(history1.history['precision'])
plt.plot(history3.history['precision'])
plt.legend(['Wide & Deep Branch','Deep Branch'])
plt.ylabel('Precision')
plt.xlabel('epochs')
plt.ylim([0.8,1])

plt.subplot(2,1,2)
plt.plot(history1.history['val_precision'])
plt.plot(history3.history['val_precision'])
plt.legend(['Wide & Deep Branch','Deep Branch'])
plt.ylabel('Precision')
plt.xlabel('epochs')
plt.ylim([0.8,1])
# Out:
# (0.8, 1.0)

# %% [markdown]
# ## Exceptional Work (1 points total)
# (0.4) The overall quality of the report as a coherent, useful, complete and polished product will be reflected here. Did you support your reasons for creating cross categories? Did you include plots and provide interpretation? Did you justify your choice of metrics?
#
# (0.6) Additional analysis
#
# (5000 level) You have free rein to provide any additional analyses and visualizations appropriate to your data.  Implement additional optimization models or statistical analysis.
#
#  ( 7000 level students - options):
# Capture the embedding weights from the deep network and (if needed) perform dimensionality reduction on the output of these embedding layers (only if needed). That is, pass the observations into the network, save the embedded weights (called embeddings), and then perform  dimensionality reduction in order to visualize results. Visualize and explain any clusters in the data.
#
# Use statistical methods to compare the performance of different models.  For classification tasks, you ight compare using the receiver operating characteristic and area under the curve. For regression tasks, you might use use Bland-Altman plots and residual variance calculations
